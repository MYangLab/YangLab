# %% [markdown]
# # Lesson 6: Smart Practices with Python
#
# At this point, you have most of the groundwork you need to write basic scripts, and much of the rest is practicing and building up your knowledge of different functions and modules until the logic and vocabulary becomes second nature.
#
# Today's lesson will explore dealing with errors while scripting and methods of outlining your code to make sure the complex script you're creating runs as you plan.
#
# ## Errors
#
# "Debugging is twice as hard as writing the code in the first place. Therefore, if you write the code as cleverly as possible, you are, by definition, not smart enough to debug it." – Brian W. Kernighan
#
# Let's be honest, most of us aren't perfect. And in our zen self-awareness, we are well-served to be sensitive to our predispositions to err in particular ways. We are probably even better served to listen to the computer when it tells us we've made a big mistake. Python can be quite good at communicating our flaws to us, if only we're receptive to the constructive criticism in its spartanly high-contrast black and white print.
#
# This morning we're going to look at common sources of error, see what to look for as feedback from Python, and learn a couple of tricks to both obviate, or if necessary, track down bugs, should they occur.
#
# If you're very lucky, an error will cause Python to give up right away, while others will cause insidious bugs that sneak through unnoticed until you present your work in lab meeting and someone calls out you on your exciting, but seemingly impossible (and ultimately bogus) result.
#
# The errors that don't give an immediate error are called **logical errors**, while those that give immediate errors are called **syntax errors**. [This link](http://geek-university.com/python/syntax-and-logical-errors/) gives a more in-depth run-down. You've already had to deal with both, by the very fact that you have been coding for the last five lessons. Here, we will talk about them explicitly.
#
# **Logical errors** are the hardest to fix, as you have no aid as you're executing the script. They are found by going through the script and making sure each part is printing what you think it should be printing, and are easier to fix as you gain better intuition about how different data types and functions work. However, even then it can be difficult to find the dumb slicing or data typing mistake. There are some strategies that if you always employ, will minimize the amount of errors or at least help you catch them early in writing code.
#
# 1. Strategic Initiative 1: Test Early, Test Often
# 2. Strategic Initiative 2: Be Verbose
# 3. Strategic Initiative 3: Be Boring, Be Obvious
#
# ### 1. Strategic Initiative 1: Test Early, Test Often
#
# There's an approach to software engineering called "Test Driven Development (TDD)". In that way of doing things, before you write a function that does something, you write code that tests it, often in a separate file. It's really convenient to use modules to do this, where you could have a test.py file that imports the relevant functions from your other modules and tests them on as many cases as it can. This also has the advantage that you notice fairly quickly when your new code breaks something that used to work. Especially in scientific programming, this isn't always practical to do, but the general ideas hold: testing is good.
#
# Even if you don't do TDD, you can save yourself lots of time by testing frequently. Debugging 100 lines of code is often more than 10 times as hard as debugging 10 lines. Writing a ton of code that generates output without checking if each component works individually does NOT make you a coding rock star; it makes you sloppy.
#
# ### 2. Strategic Initiative 2: Be Verbose
#
# "Errors should never pass silently." -- The Zen of Python, by Tim Peters
#
# One of the easiest ways to debug code is to print out the value of variables at the point things start going wrong. Of course, if you knew where things were going wrong, you would probably know what was going wrong in the first place, so to find this, a divide-and-conquer approach is often fastest. Start out by putting a bunch of print statements in throughout your code, then narrow things down gradually until you're right at the broken line of code.
#
# It's not a bad idea to include these print statements in moderation before you need them. If you think there will be a subset of your data that will fail a logical test, setup your **if** and **else** statements to report the incidence of failure.
#
# For instance, in nested loops, I often will print the variables belonging to each for loop, making sure that what is printed out is what I expect.
#
# ### 3. Strategic Initiative 3: Be Boring, Be Obvious
#
# "Programs must be written for people to read, and only incidentally for machines to execute." --Structure and Interpretation of Computer Programs Hal Abelson and Gerald Jay Sussman
#
# As you get better at coding, you will start to take shortcuts and combine lines. As soon as something doesn't behave as you expect, you should decompose your compound statements, as this is a common source of error.

# %%
pd="/Users/myang/YangLab/PythonBootcamp/resources/"
myfile = open(pd+"seq.fasta",mode='r')
myfile = myfile.read()

print ("Note that the compound and expanded versions give the same result.")

##COMPOUND
xx = {int(myfile[5:7].strip()):myfile[7:40].strip()+myfile[40:72].strip()+myfile[72:].strip()}[int(myfile[5:7].strip())][3:8]
print (xx)

##EXPANDED
myl1 = myfile[5:7]
myl1 = myl1.strip()
myl2 = myfile[7:40]
myl2 = myl2.strip()
myl3 = myfile[40:72]
myl3 = myl3.strip()
myl4 = myfile[72:]
myl4 = myl4.strip()
mykey = int(myl1)
myseq1 = myl2+myl3+myl4
mydict = {mykey:myseq1}
xx = mydict[mykey][3:8]
print (xx)

# %% [markdown]
# If any one of these parts were wrong, then in the compound form, **xx** would be wrong, but it would be difficult to figure out which part caused the problem. In the expanded form, **xx** would be wrong, but you can print several of the interim outputs to see where you get something unexpected.
#
# On a related note, it's good practice to comment your code. The [Python Style Guide](https://www.python.org/dev/peps/pep-0008/) has some good recommendations about comments. Anything you did that required some thinking on your part should ideally be commented, since you might come back to the code weeks or months later and have forgotten why you did it that way. Also try to keep your comments up to date with the code.

# %%
pd="/Users/myang/YangLab/PythonBootcamp/resources/"
myfile = open(pd+"seq.fasta",mode='r')
myfile = myfile.read()

xx = {int(myfile[5:7].strip()):myfile[7:40].strip()+myfile[40:72].strip()+myfile[72:].strip()}[int(myfile[7].strip())][3:8]

print (xx)

##Can we find the error? Break down the parts of this compound code to figure it out.

# %% [markdown]
# **Syntax errors** are easier to fix, as they are mistakes in the "grammar" of the language. The script cannot finish, and most importantly, it will give you an error message.

# %%
for x in [1,2,3]
    print (x)

# %% [markdown]
# The above code has an error. If you run it, you see several lines displaying the error.
#
# ```python
#   File "<ipython-input-10-608b103f78ac>", line 1
#     for x in [1,2,3]
#                     ^
# SyntaxError: invalid syntax
# ```
#
# First, it specifies the file, which in this case is a cell in ipython. Then, it specifies what line in the file, or here, *line 1*. It displays that line and points an arrow to where they think the problem is (it is sometimes further from the place you would think!). Finally, it gives the type of error, "SyntaxError: invalid syntax", showing that we have a syntax error. And we do, we are missing a colon to indicate the for loop.

# %%
biodept = ['Wu', 'Yang', 'Stenger','Pierce']
print (biodept[10])

# %% [markdown]
# Another common error is the IndexError:
#
# ```python
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-9d37abefe9a1> in <module>
#       1 biodept = ['Wu', 'Yang', 'Stenger','Pierce']
# ----> 2 print (biodept[10])
#
# IndexError: list index out of range
# ```
#
# Here, it points at the line causing a problem and says "IndexError: list index out of range". Indeed, we are asking for the tenth element, which does not exist.

# %% [markdown]
# ## Easier to Ask Forgiveness than Permission: Try and Except
#
# "Errors should never pass silently. Unless explicitly silenced." -- The Zen of Python, by Tim Peters
#
# The **try** and **except** statements let us attempt to do something that may or may not work, and then respond appropriately if or when something goes wrong. For example, sometimes the file we want to work with isn't available for some reason (and if you're really lucky, it's only because you forgot to plug in an external hard drive or you're in the wrong folder).
#
# Run the following:

# %%
fh = open("this_file_contains_our_ticket_to_the_nobel_prize.txt",'r')

# %% [markdown]
# When a file does not exist, we get a **FileNotFoundError** stopping the script completely. However, if we anticipate a file might not exist and want the script to keep running if an error occurs, we can use **try** and **except**.

# %%
try:
    fh = open("this_file_contains_our_ticket_to_the_nobel_prize.txt",'r')
except OSError: ##except FileNotFoundError:
    print ("The ticket to the Nobel does not exist. I guess we got to go about it the normal way.")

# %% [markdown]
# Notice that both **OSError** and **FileNotFoundError** work with the **except**. This is because the **FileNotFoundError** is a subcategory of **OSError**. See a hierarchy of errors [here](https://airbrake.io/blog/python-exception-handling/class-hierarchy).
#
# This means that when there is an **OSError**, rather than making python fail, the program should do something in particular (print a line saying as much, in this case).
#
# Sometimes you might have a section of code where multiple things could go wrong. In that case, you can respond to each of them appropriately using multiple except statements. It's even possible to have an except statement without listing the type of error, which will deal with anything not handled by one of the previous except statements.
#
# Save the following to a file called "lesson6_errors.py" and try the following in a Bash Terminal:
#
# ```bash
# python lesson6_errors1.py 1
# python lesson6_errors1.py a
# python lesson6_errors1.py
# python lesson6_errors1.py 0
# ```

# %%
# %%writefile /Users/myang/YangLab/PythonBootcamp/Lesson6/lesson6_errors1.py

import sys
 
def dividetwo(num):
    return 2/num
 
try:
    print (dividetwo(float(sys.argv[1])))
except ValueError:
    print ('not a float!')
except IndexError:
    print ('did you put a number in the command line?')
except:
    print ('Some other error!')

# %%
# %%bash
#
# pd="/Users/myang/YangLab/PythonBootcamp/Lesson6/"
# python ${pd}lesson6_errors1.py 0

# %% [markdown]
# # It's considered slightly bad form, however, to have a catch-all **except** block. If you didn't anticipate the error, it will probably be helpful to you to get the default error message, even if it is a little arcane, rather than a message like the above, which is pretty darn vague.
#
# Another list with the default kinds of errors (also called "exceptions") with more description is shown here: [the list of Built-in Exceptions](http://docs.python.org/library/exceptions.html) in the Python Documentation.
#
# ### Else and Finally
#
# Similar to the use of **else** in for and while loops, anything in an **else** block will run *only if* no errors happened. On the other hand, anything in a **finally** block runs after the try/except blocks, and will run regardless of whether an exception was thrown. If there was an exception, it doesn't stop it from being thrown, it just waits a bit before it does.

# %%
def divide(x,y):
    try:
        result = x/y
    except ZeroDivisionError:
        print ("Warning: divide by zero!")
        return float('NaN') #Not a number
    else:
        return 'myresult!',result
    finally:
        print (x,y,"executing final clause")

print ("Note that divide(2,1) runs normally, but it prints the 'finally' condition")
print (divide(2,1))
print ()
print ("Note that divide(2,0) goes to the 'except' condition and returns what's in there - the 'finally' condition is also printed")
print (divide(2,0))
print ()
print ("Note that divide('A','B') prints the 'finally' condition just fine, but ultimately gives an error")
print (divide('A','B'))

# %% [markdown]
# The first case made it through the division just fine.
#
# The second case raised an exception (a division by zero error), but we anticipated that, so we replace it with a special Not a Number value, and move on.
#
# The third case we found an exception that we didn't anticipate. The exception came up, so we still ran the finally clause, but then raised the exception. This might be useful if you want the program to still finish up despite the error (output whatever has already been done by the script, perhaps).

# %% [markdown]
# ## Help yourself!
#
# You have learned a bit about how to deal with errors, and the rest of the lesson will be on helpful commands and ways of thinking to help you write efficient and useful code.
#
# Try out the function **dir**. With no argument, it shows a list of all available functions and variables. Don't worry too much about the **__variable__** you see - these are internal objects and not ones we generally mess with.
#
# If you add an argument, such as a variable you have made, it shows all the possible methods that can act upon that object.
#
# Another function **help** takes the argument of the method or function and will give a short summary of what the argument does. This is much like using the 'tab' key or the ?, but a slightly different way of viewing things.

# %%
x = 1
dir(x)

#After looking at what dir() does, uncomment help() to see what it does.
#help(x)

# %% [markdown]
# ### Profiling
#
# One thing pretty valuable that IPython lets us do easily is "profiling" our code, which is a way to see where all the time is being spent. Now, I've said earlier that it's better to do something slow and simply, than (potentially) super-fast and complicated, but if you find that you're doing something a lot, it may be worthwhile to spend some time figuring out how to make it faster (especially if that comes at a low complexity cost).
#
# Save the following fasta parser to the file "lesson6_fastaparser1.py".

# %%
# %%writefile /Users/myang/YangLab/PythonBootcamp/Lesson6/lesson6_fastaparser1.py

import sys

def fastaParser(filename):
   current_gene = ""
   genes = {}
   fh = open(filename, 'r')
 
   for line in fh:
       line = line.strip()
       if line.startswith('>'):
           current_gene = line[1:]
           genes[current_gene] = ''
       else:
            join(genes, current_gene, line) 
   return genes
 
def join(gene_dict, gene, line):
    gene_dict[gene] += line
 
genomes = fastaParser(sys.argv[1])
 
print ("There are", len(genomes), "sequences.")

# %% [markdown]
# Try to type **ipython** into your terminal. This should start an interactive python console. If that doesn't work (e.g. Terminal says 'command not found'), go to "Anaconda Navigator" in your Applications or Startup menu. From there, find the "Jupyter QtConsole". This should also create an interactive python console.
#
# In this interactive python console, you can use not only python commands but also Unix commands! Navigate to your lessons/ directory containing your "lesson6_fastaparser.py" and run it as such:
#
# ```bash
# run -p ../Lesson6/lesson6_fastaparser1.py ../resources/seq.fasta
# ```
#
# Now try out the "cerevisiae_genome.fasta" file.
#
# A "less" screen should show up containing at the top the total time to run and then breaking down the time to run different commands that make the Python script work.
#
# ```
#          611013 function calls (611012 primitive calls) in 6.346 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    202628    6.070    0.000    6.070    0.000 lesson6_fastaparser1.py:18(join)
#         1    0.201    0.201    6.345    6.345 lesson6_fastaparser1.py:4(fastaParser)
#    202650    0.040    0.000    0.040    0.000 {method 'startswith' of 'str' objects}
#    202645    0.025    0.000    0.025    0.000 {method 'strip' of 'str' objects}
#      1511    0.004    0.000    0.004    0.000 {built-in method _codecs.utf_8_decode}
#      1511    0.004    0.000    0.008    0.000 codecs.py:319(decode)
#         3    0.000    0.000    0.000    0.000 {built-in method io.open}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#         1    0.000    0.000    6.346    6.346 interactiveshell.py:2676(safe_execfile)
#       2/1    0.000    0.000    6.346    6.346 {built-in method builtins.exec}
#         1    0.000    0.000    6.345    6.345 lesson6_fastaparser1.py:2(<module>)
#         1    0.000    0.000    0.000    0.000 {built-in method posix.getcwd}
#         1    0.000    0.000    6.345    6.345 py3compat.py:164(execfile)
#         2    0.000    0.000    0.000    0.000 _bootlocale.py:33(getpreferredencoding)
#         2    0.000    0.000    0.000    0.000 codecs.py:309(__init__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#
# ...
# ```
#
# We can see it took about 6.35 seconds total to complete the run, and then we see that different steps within the python script were recorded and then the times were listed from longest to shortest. Here, we see the **join** function took the longest, taking ~6.07 seconds.
#
# What is happening is that the way we are joining strings is by concatenating, using "+=", which is fine for short strings, but gets very slow the longer the strings are.
#
# We can instead join strings a different way - repeat the python run for `cerevisiae_genome.fasta`, but this time, use the parser below: `lesson6_fastaparser2.py`:

# %%
# %%writefile /Users/myang/YangLab/PythonBootcamp/Lesson6/lesson6_fastaparser2.py

import sys

def fastaParser(filename):
   current_gene = ""
   genes = {}
   fh = open(filename, 'r')
 
   for line in fh:
       line = line.strip()
       if line.startswith('>'):
           current_gene = line[1:]
           genes[current_gene] = []  ##CHANGE
       else: 
            join(genes, current_gene, line) 
   
    ##CHANGE ADDED FOR LOOP
   for gene in genes:
       genes[gene] = ''.join(genes[gene])
   return genes
 
def join(gene_dict, gene, line):
    gene_dict[gene].append(line)   ##CHANGE
 
genomes = fastaParser(sys.argv[1])
 
print ("There are", len(genomes), "sequences.")

# %% [markdown]
# ```bash
#          813658 function calls (813657 primitive calls) in 0.259 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.125    0.125    0.252    0.252 lesson6_fastaparser2.py:4(fastaParser)
#    202628    0.041    0.000    0.055    0.000 lesson6_fastaparser2.py:22(join)
#    202645    0.032    0.000    0.032    0.000 {method 'strip' of 'str' objects}
#    202650    0.030    0.000    0.030    0.000 {method 'startswith' of 'str' objects}
#    202635    0.014    0.000    0.014    0.000 {method 'append' of 'list' objects}
#        18    0.008    0.000    0.008    0.000 {method 'join' of 'str' objects}
#         1    0.006    0.006    0.006    0.006 {method 'read' of '_io.BufferedReader' objects}
#      1511    0.002    0.000    0.002    0.000 {built-in method _codecs.utf_8_decode}
#      1511    0.001    0.000    0.003    0.000 codecs.py:319(decode)
#         1    0.001    0.001    0.001    0.001 {built-in method builtins.compile}
#         3    0.000    0.000    0.000    0.000 {built-in method io.open}
#       2/1    0.000    0.000    0.259    0.259 {built-in method builtins.exec}
#         1    0.000    0.000    0.252    0.252 lesson6_fastaparser2.py:2(<module>)
#
# ...
# ```
#
# Now, the second script only took 0.259 seconds, and the **join** function is much faster.
#
# The change is that rather than building a string, we are adding strings to a list. Lists have been optimized such that you can add to them, and they don't slow down as they get longer. Then, once everything is in a list, we go through for all of the keys and use the string "join" method (which is different from the join function we wrote), which will combine all the items in the list, putting an empty string between them.
#
# So now we see that our second join function is about 100 times faster, and we spend almost no time at all in the extra string joining. Plus, the code is not really that much more complicated.
#
# Here, the difference between 6 seconds and 0.259 seconds doesn't seem like much, but the `cerevisiae_genome.fasta` file is not very big. Imagine if you wanted to do the same, but on a much bigger file - those tiny seconds start adding up and can make a difference between whether your code runs for a week versus an hour!
#
# A general piece of advice is not to try to optimize your code until *after* you've profiled it. Otherwise, you might spend a lot of time making something largely irrelevant twice as fast, but only improve your total speed by a very tiny amount.
#
# For a link to common errors to consider, look [here](https://pythonforbiologists.com/29-common-beginner-errors-on-one-page). There's a handy PDF graphic that might be good to print and keep nearby until you're more comfortable with troubleshooting errors.

# %% [markdown]
# ## Stubbing and the 'pass' statement
#
# Lastly, we have to think about how we organize our code. A useful thing to do before beginning is to write out some ***pseudocode***. This is not real code, but you laying out some framework within which your code details will be put in - generally this is not something you can run, but more like note-taking so you can start visualizing what you need to do to bring all the different components of your code together.
#
# When we write complicated code, we need to decompose it into simpler parts. This is an intuitive concept, and one that we've touched on before. ***Stubbing*** is writing what your program should be doing (in the correct form for a python script to run!), without actually getting around to filling in the details. It's like writing an outline of a paper.
#
# Let's say that we want to make a program that gambles online and makes money for you so that you are free to pursue the standard academic career path of postdoctoral positions ad infinitum. I would start stubbing such a program with some big picture ideas: the program has to log on to a gambling server, keep track of your balance, and play until you win or go home.
#
# ```python
# import sys
#
# import internet
# import games
#
# account_name = sys.argv[1]
# password = sys.argv[2]
#
#
# balance, session_info = internet.logOnToIllegalGamblingServer(account_name,password)
#
# while balance > 0:
#
#     balance = games.playGame('slots',balance,session_info)
#
#     if balance > 1000000000:
#
#         print ('Congratulations you are a billionare!')
#         internet.logOffFromIllegalGamblingServer()
#         sys.exit()
#
# print ('Darn')
# internet.logOffFromIllegalGamblingServer()
# ```
#
# __internet__ and __games__ are not built into python - we'll have to write the functions in them ourselves eventually. However, now we have a better idea of what these functions should look like, and what they need to do. For now, let's use a new concept to fill these functions in and allow us to run and test this code: the statement __pass__. It's pretty simple: it does nothing. Although this sounds somewhat pointless, in this case it allows you to write little function stubs without Python (or your text editor) complaining. However, it pops up in other places as well, usually as a shortcut where you mean to write more code later. This could be in an __if__ or __else__ statement or while raising an exception. Each of those cases requires something after the colon for it to be valid Python, and **pass** is a valid way to put in something that does nothing. We won't cover those applications here, but keep them in mind while you're programming: we encourage you to try it out.
#
# Notice also that in each function, I write a few comments to help me remember what I want to put in the function, and what I want to get out of it.
#
# _internet.py_
# ```python
# ##input: two strings, account_name and password
# ##output: the balance and session info for the associated account
# def logOnToIllegalGamblingServer(account_name,password):
#     pass
#
# ##logs the user off from the server
# def logOffFromIllegalGamblingServer():
#     pass
# ```
#
# _games.py_
# ```python
# def playGame(game_name,balance,session_info):
#     ##input: a string game_name, an int balance, and the session information
#     ##output: the new balance after playing a round of a a game
#     if game_name == 'slots':
#         balance = playSlots(balance,session_info)
#     else:
#         print (f"Game {game_name} not found, please pick another")
#     return balance
#
# def playSlots(balance,session_info):
#     ##input: an int balance and the session info
#     ##output: the new balance after playing a round of slots
#     current_bet = getBet(balance)
#     balance = balance - current_bet
#     current_result = pullLever()
#     winnings = calcWinnings(current_result,current_bet)
#     balance = balance + winnings
#     return balance
#
# def getBet(balance):
#     ##input: an int balance
#     ##output: a valid bet given the current balance
#     ##prompts the user to make a bet
#     pass
#
# def pullLever():
#     ##output: a list of the results of a single slot machine game
#     pass
#
# def calcWinnings(current_result,current_bet):
#     ##input: a list of results from a slot machine game, and an int bet
#     ##output: an int of the total winnings (if any) earned from the game
#     pass
# ```

# %% [markdown]
# ## Summing up
# I've already taught you the basics you need to write simple python scripts. The next three lessons mostly focus on introducing you several useful modules, including ones for plotting data (**matplotlib**), statistical analyses (**scipy.stats**), using arrays (**numpy**), and running UNIX commands from python (**subprocess**).
#
# By the end of Lesson 9, I want you to be able to do a small project exploring the data in one or more of the following datasets. We currently have one dataset downloaded: the [Fu et al. (2016)](http://www.nature.com/nature/journal/v534/n7606/full/nature17993.html) dataset we downloaded already ("51.2.2M" and "archaic" geno files).
#
# Data in a similar format for these individuals and many more can be found at the following [link](https://reich.hms.harvard.edu/downloadable-genotypes-present-day-and-ancient-dna-data-compiled-published-papers). The Reich Lab, a highly regarded ancient DNA lab headed by David Reich at Harvard Medical School, has spent a lot of effort compiling data from many different papers (some present-day but lots of ancient humans) into one dataset. What's nice is that they've done a lot of compiling for you. This means that if the populations you want to compare are in this dataset, you don't need to go through all the steps of merging data and making sure the method of calling genotypes was consistent - they've done it for you. Because of that, we'll start with their data.
#
# Because this **geno** file is bigger (2 Gb), let's move onto the server.

# %% [markdown]
# ## Server Login
#
# After turning on your UR VPN, in your Terminal, type the following:
#
# ```bash
# ssh <username>@genome
# ```
#
# Note that <xxx> indicates that you should replace that line with the descriptor inside. So, <username> would be the username created for you on genome . This is usually your web ID (five letters and numbers), but see me if it doesn't work.
#
# If this is the first time, it will doublecheck you want to go to this server. Reply 'yes' and press enter.
#
# It will ask for your password - this is usually your University of Richmond password. Put in your password and press enter. The Terminal will not show the password, so type carefully.
#
# If you don't get an error, and you now see something like the following, then you have successfully logged in.

# %% [markdown]
# ```bash
# (base) m1-bio-myang:resources myang$ ssh myang@genome
#
# This is a University of Richmond (UofR) computer system.
#
# All data contained within UofR computer systems is owned by
# the University of Richmond, and may be monitored, intercepted,
# recorded, read, copied, or captured in any manner and
# disclosed in any manner, by authorized personnel.
#
# THERE IS NO RIGHT OF PRIVACY IN THIS SYSTEM.
#
# System personnel may disclose any potential evidence of crime found on
# UofR computer systems for any reason.
#
# USE OF THIS SYSTEM BY ANY USER, AUTHORIZED OR UNAUTHORIZED,
# CONSTITUTES CONSENT TO THIS MONITORING, INTERCEPTION,
# RECORDING, READING, COPYING, or CAPTURING and DISCLOSURE.
#
# Last login: Mon Jun  1 11:06:49 2020 from 172.17.8.99
# ```

# %% [markdown]
# Remember that the server has no GUI like your computer has. Thus, using Unix commands is the best way to navigate through the server.
#
# Note the following:
# 1. You are in **your** HOME directory. This has the file path `/home/<username>/`. This folder cannot be accessed by anyone else, except the system administrator. This is a space no one else can access, where you can make new folders and files and organize as you see fit. You should NOT share your username and password with anyone else, as a log of what occurs on the server is tied to your username, and if something goes wrong, the first thing that occurs is the system administrator looks to see under which account something went wrong (this is also helpful in troubleshooting errors as well!). Type **ls** to see what are default folders, and feel free to make new folders to organize this space as you see fit.
# 2. `/home/classes/myanglab/` - There is a shared directory in a different directory on the server. In this folder, you have access to almost everything inside. This folder is where you put anything you want me to see. Create a directory in this folder with your preferred name ( `mkdir <your preferred name>` ). You can choose to completely work within this directory (my suggestion if you're just starting), or you can work in your HOME directory and copy files to this folder, or you can use some combination of the two.
# 3. Note the `/home/classes/myanglab/data/` folder - this is where data I download from the internet will be located. Go explore this folder - the 1240K data is [what I downloaded from the Reich Lab website](https://reich.hms.harvard.edu/downloadable-genotypes-present-day-and-ancient-dna-data-compiled-published-papers). Does the format look familiar to you?
#
# We'll largely be working from the shared directory; expect that the directory will keep growing as we get our projects started. Let me know if you have any questions!

# %% [markdown]
# ## Remotely using Jupyter Notebook
#
# The last thing that'd be really nice to know to get started on the server is how to use Jupyter Notebook. **Anaconda** is not yet installed on the genome server, so for now, we're going to install python libraries using a different method.
#
# In your Terminal, type the following:
#
# ```bash
# pip3 install jupyter --user
# pip3 install numpy —user
# pip3 install matplotlib --user
# pip3 install pandas --user
# ```
#
# The `--user` tells your account to install locally to your server. This is to protect the server - we don't want to mess up the structure of the server, so only IT has administrative access - we need to locally install or ask IT to install something for us - this includes me too! If you need something installed, ask me, and if I can't do it, I'll ask UR's computer help desk.
#
# The above four commands checks to see if Jupyter, Numpy, Matplotlib, and Pandas are installed, and if not, it downloads them from the internet and installs them. These four libraries are common ones you will likely use over and over again, and if there are others you want to use, `pip3 install <libraryname> --user` will hopefully do it!
#
# Make sure you're in the directory you want to work from (either `/home/classes/myanglab` or `/home/<your username>`).
#
# Now, type `jupyter notebook --no-browser`.
#
# For me, my output was:
#
# ```
# [I 15:47:53.577 NotebookApp] Serving notebooks from local directory: /home/classes/myanglab
# [I 15:47:53.577 NotebookApp] The Jupyter Notebook is running at:
# [I 15:47:53.577 NotebookApp] http://localhost:8888/
# [I 15:47:53.577 NotebookApp] Use Control-C to stop this server and shut down all kernels (twice to skip confirmation).
# ^C[I 15:48:00.302 NotebookApp] interrupted
# Serving notebooks from local directory: /home/classes/myanglab
# 0 active kernels
# The Jupyter Notebook is running at:
# http://localhost:8888/
# Shutdown this notebook server (y/[n])? ^C[C 15:48:01.031 NotebookApp] received signal 2, stopping
# [I 15:48:01.032 NotebookApp] Shutting down 0 kernels
# ```
#
# Find the `http://localhost:####/...` link.
#
# Copy the entire link and note the four digit port number.
#
# Now, on your computer, open a new Terminal.
#
# Type the following:
#
# ```bash
# ssh -NfL localhost:####:localhost:#### <username>@genome
# ```
#
# The #### is the port number you just found - for me here, it's 8888. It should similarly prompt you for your password. Note that you are using `ssh`, like you normally would, but the extra options tell your computer to connect to the genome server at the specified port (####), which has Jupyter Notebook running.
#
# If it works, then after you press enter, no error should occur! Go to your web browser and paste in the link you just copied. This should now open a page in your directory on the server!

# %% [markdown]
# ## Passwords and screen
#
# The annoying thing with the server is that you have to keep logging on and making a new Jupyter Notebook. But, we can make that easier.
#
# ### Passwords
#
# You can set up a key tied to your laptop so that you don't have to log in with your super long password every single time. Look at the following [link](https://www.thegeekstuff.com/2008/11/3-steps-to-perform-ssh-login-without-password-using-ssh-keygen-ssh-copy-id/). See if you can follow those instructions, so you can log in and out of the genome server without a password (you could choose for a shorter password, but on my own laptop, it's not a big deal).
#
# ### Screen
# The problem with signing in and out of the server is you can't easily just leave things running in the background. When you close your computer and reopen it, all the applications you were using are still running. The server usually doesn't do that unless you specify that. To make matters worse, if you aren't active for an hour, the server where automatically sign you off as a protective measure.
#
# To run things in the background, and then revisit them, `screen` is what I like to use. It's a way to create a new 'screen' to run things in, and when you switch back to your main 'screen', it's still running in the background. It's a bit confusing at first to keep track of screens, so let's just do something simple here - set up a Jupyter Notebook to run continuously in a 'screen'. Then, if you logout, the notebook will still run, so you can leave it up in perpetuity.
#
# On Terminal, log into the server. Now type `screen` and press Enter.
#
# You are now in a new 'screen' in Terminal!
#
# Change to the appropriate directory and open a Jupyter Notebook remotely. Then, type Ctrl+A+D to exit the screen. When you are back in the regular server, type `screen -r`. That is how you get back in.
#
# Try typing just `screen` again. Note that you've now made a new screen! Again use Ctrl+A+D to exit and type in screen -r. Now you should have a list - add the number to specify which screen.
#
# OPTIONAL: You can use `screen -S <name you make up>` to give your screen a name, so you can type `screen -r <name you made up>` to access your screen. This may be more useful as you can make a name that helps you remember which screen you did what.
#
# Now, you can have Jupyter Notebook running in the background (and whatever else, if you run a script that takes a while).
#
# Check in with me here, if you haven't contacted me to troubleshoot already, to let me know you successfully accessed the server and tried the above!
